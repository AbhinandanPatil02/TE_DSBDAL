# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
print(data.columns)
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'variety'], dtype='object')

# %%
data=data.rename(
    columns={
        'sepal.length':'sl',
        'sepal.width':'sw',
        'petal.length':'pl',
        'petal.width':'pw'
        })

# %%
data.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
sns.histplot(data=data,x='sl',bins=15)
# Out:
# <Axes: xlabel='sl', ylabel='Count'>

# %%
sns.histplot(data=data,x='pl',bins=15)
# Out:
# <Axes: xlabel='pl', ylabel='Count'>

# %%
sns.histplot(data=data,x='sw',bins=15)
# Out:
# <Axes: xlabel='sw', ylabel='Count'>

# %%
sns.histplot(data=data,x='pw',bins=15)
# Out:
# <Axes: xlabel='pw', ylabel='Count'>

# %%
sns.boxplot(data.drop('variety',axis=1))
# Out:
# <Axes: >

# %%
sns.boxplot(data=data,x='variety',y='sl')
# Out:
# <Axes: xlabel='variety', ylabel='sl'>

# %%
sns.boxplot(data=data,x='variety',y='pl')
# Out:
# <Axes: xlabel='variety', ylabel='pl'>

# %%
sns.boxplot(data=data,x='variety',y='sw')
# Out:
# <Axes: xlabel='variety', ylabel='sw'>

# %%
sns.boxplot(data=data,x='variety',y='pw')
# Out:
# <Axes: xlabel='variety', ylabel='pw'>

# %%
sns.kdeplot(data=data,x='sl')
# Out:
# <Axes: xlabel='sl', ylabel='Density'>

# %%
sns.kdeplot(data=data,x='pl')
# Out:
# <Axes: xlabel='pl', ylabel='Density'>

# %%
sns.kdeplot(data=data,x='sw')
# Out:
# <Axes: xlabel='sw', ylabel='Density'>

# %%
sns.kdeplot(data=data,x='pw')
# Out:
# <Axes: xlabel='pw', ylabel='Density'>
